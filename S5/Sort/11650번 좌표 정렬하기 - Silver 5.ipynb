# %% [markdown]
# # 11650번 좌표 정렬하기 - Silver 5
#
# ![image.png](attachment:image.png)

# %%
n = int(input())

point = [list(map(int,input().split())) for _ in range(n)]
# Out:
# 5
# 1 1
# 1 -1
# 3 4
# 2 2
# 3 3

# %%
for _ in sorted(point):
    print(*_)
# Out:
# 1 -1
# 1 1
# 2 2
# 3 3
# 3 4
