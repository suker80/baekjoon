# %% [markdown]
# # 1300번 K번째 수 - Gold 4
#
# #### 알고리즘 분류 : 이분 탐색
#
# ![image.png](attachment:image.png)

# %%
n = int(input())
k = int(input())

s,e = 1,k

while s<= e:
    mid = (s+e)//2
    cnt = 0
    for i in range(1,n+1):
        cnt += min(n,mid//i)
    if cnt < k:
        s = mid+ 1
    else:
        e = mid-1
print(s)
