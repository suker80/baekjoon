# %% [markdown]
# # 2023번 신기한 소수 - Gold 5
#
# ![image.png](attachment:image.png)

# %%
n = int(input())

end = 10**(n+1)
prime =[2,3,5,7,23,29,31,37,53,59,71,73,79]

# %%
def solution(N):
    answer = list()
    stack = list()
    stack.append(2)
    stack.append(3)
    stack.append(5)
    stack.append(7)
    while stack:
        num = stack.pop()
        if 10**(N-1)<=num<10**N:
            answer.append(num)
            continue
        for i in range(10):
            newnum = num*10+i
            check=True
            for j in range(2,newnum//2):
                if newnum%j ==0:
                    check=False
                    break
            if check==True:
                stack.append(newnum)
    return sorted(answer)


   
    return answer
def main():
    N=int(input())
    answer = solution(N)
    for i in answer:
        print(i)

main()
